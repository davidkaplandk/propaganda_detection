# %%
PROMPT_TEMPLATE = """
You are an expert in propaganda analysis. Analyze the following text. 
Always keep in mind that you are only looking for russian propaganda, not any other type of propaganda. Any other type of propaganda should be ignored and labeled as "No Propaganda".

Text:
"{text}"

1. Identify the main label that best describes the text.
2. Identify the high level label that best describes the text.

Main labels:
•1 — Loaded language: Use emotionally charged or stereotyped wording to sway feelings.
•2 — Appeal to fear/prejudice: Try to persuade by warning of frightening outcomes or playing on biases.
•3 — Doubt: Undermine credibility by questioning motives, facts, or sources.
•4 — Name calling/labeling: Attack a person or group with insulting or demeaning labels.
•5 — Flag-waving: Justify a position by appealing to patriotism or group identity.
•6 — Exaggeration or minimization: Overstate benefits/harms or downplay them to mislead.
•7 — Causal oversimplification: Claim a simple cause for a complex issue or outcome.
•8 — Red herring: Introduce an irrelevant point to distract from the main issue.
•9 — Black-and-white fallacy: Present only two options and ignore reasonable alternatives.
•10 — Reductio ad hitlerum: Dismiss an idea by associating it with Nazis/Hitler or similarly reviled groups.
•11 — Appeal to authority: Cite an authority’s support as proof rather than evidence.
•12 — Straw man: Misrepresent an opponent’s argument, then refute the weaker version.
•13 — Thought-terminating cliches: Use stock phrases that shut down questioning or debate.
•14 — Whataboutism: Deflect criticism by accusing others of similar or worse behavior.
•15 — Slogans: Use a short, catchy phrase to promote an idea.
•16 — Bandwagon: Argue something is good/true because it’s popular or widely adopted.
•17 — Repetition: Repeat the same claim or phrase many times to make it stick.
•18 — no_propaganda: No relevant propaganda detected.

High level labels:

Group 1: Patriotic & Catchy Appeals  
    (Appeal through patriotism, group identity, or memorable slogans.)  
    • (5) Flag-waving – appeal to patriotism or group identity.  
    • (15) Slogans – short, catchy phrases to promote an idea.  

Group 2: Popularity Appeals  
    (Persuade by presenting an idea as popular or widely accepted.)  
    • (16) Bandwagon – argue something is good/true because it’s popular.  

Group 3: Deflections & Distractions  
    (Shift attention away from the issue through diversion or oversimplification.)  
    • (14) Whataboutism – deflect criticism by pointing to others’ behavior.  
    • (17) Repetition – repeat a claim to make it stick.  
    • (7) Causal oversimplification – claim a simple cause for a complex issue.  
    • (8) Red herring – distract with irrelevant points.  

Group 4: Emotional & Loaded Persuasion  
    (Exploit emotions or exaggeration to influence perception.)  
    • (1) Loaded language – emotionally charged wording.  
    • (10) Reductio ad hitlerum – dismiss by linking to Nazis/Hitler.  
    • (11) Appeal to authority – rely on authority instead of evidence.  
    • (2) Appeal to fear/prejudice – warn of frightening outcomes or biases.  
    • (4) Name-calling/labeling – attack with insulting labels.  
    • (6) Exaggeration or minimization – overstate or downplay effects.  

Group 5: Argument Manipulations  
    (Manipulate reasoning by misrepresenting arguments or limiting choices.)  
    • (12) Straw man – misrepresent opponent’s argument.  
    • (13) Thought-terminating clichés – shut down debate with stock phrases.  
    • (3) Doubt – question credibility or motives.  
    • (9) Black-and-white fallacy – present only two options.  

Group 6: No Propaganda  
    (Text contains no relevant propaganda techniques.)  
    • (18) no_propaganda – no relevant propaganda detected

Now return the labels in a JSON format with the following structure:
{{"main": integer,"high": integer}}

Follow the json format strictly. Do not add any additional text or explanations. Just use the integers for labeling, no strings.
Remember to always return Integers only! Only return one integer that best describes the text. Never return multiple integers or a list of integers!
"""

# %%
from openai import OpenAI
import json
import re
import pandas as pd

client = OpenAI()

def analyze_propaganda(text_to_analyze, max_retries=3):
    """Call OpenAI to get both 'main' and 'high' integer labels for a text."""
    if not text_to_analyze.strip():
        return None, None, "Empty input"

    try:
        full_prompt = PROMPT_TEMPLATE.format(text=text_to_analyze)
    except Exception as e:
        return None, None, f"Prompt error: {e}"

    last_model_output = None

    for attempt in range(1, max_retries + 1):
        try:
            response = client.chat.completions.create(
                model="ft:gpt-4.1-nano-2025-04-14:veronika-solopova::C5zhnCWM",
                messages=[{"role": "user", "content": full_prompt}],
                temperature=0,
                response_format={
                    "type": "json_schema",
                    "json_schema": {
                        "name": "propaganda_schema",
                        "schema": {
                            "type": "object",
                            "properties": {
                                "main": {"type": "integer"},
                                "high": {"type": "integer"}
                            },
                            "required": ["main", "high"]
                        }
                    }
                },
                max_tokens=128,
            )

            model_output_text = response.choices[0].message.content.strip()
            last_model_output = model_output_text

            # 🔍 Print raw model output for debugging
            print("\n📨 Raw model output:\n", model_output_text)

            json_match = re.search(r'\{(?:.|\n)*\}', model_output_text)
            if not json_match:
                raise ValueError("No JSON object found in model output.")

            parsed_json = json.loads(json_match.group(0).strip("` \n"))
            main_label = parsed_json.get("main")
            high_label = parsed_json.get("high")

            if not isinstance(main_label, int) or not isinstance(high_label, int):
                raise ValueError(f"Labels must be integers, got: main={main_label}, high={high_label}")

            return main_label, high_label, None

        except (json.JSONDecodeError, ValueError, KeyError) as e:
            if attempt == max_retries:
                return None, None, f"Parsing failed after {max_retries} attempts: {e}\nRaw output: {last_model_output}"
        except Exception as e:
            if attempt == max_retries:
                return None, None, f"Unexpected error after {max_retries} attempts: {e}\nRaw output: {last_model_output}"

    return None, None, "Unknown error"


def process_pickle(input_pickle_path, output_json_path):
    """Process a pickle file and return both 'main' and 'high' labels for each text."""
    try:
        df = pd.read_pickle(input_pickle_path)
        print(f"✅ Loaded pickle '{input_pickle_path}' with {len(df)} rows.")
    except Exception as e:
        print(f"❌ Error loading pickle: {e}")
        return

    if not {"text", "id"}.issubset(df.columns):
        print("❌ DataFrame must contain both 'text' and 'id' columns.")
        return

    processed_data = []

    for i, row in df.iterrows():
        record_id = row["id"]
        text = str(row["text"]).strip()

        print(f"\n🔍 Processing record {i + 1} (ID: {record_id})...")
        main_label, high_label, error_message = analyze_propaganda(text)

        record = {
            "id": record_id,
            "text": text,
            "main": main_label,
            "high": high_label,
            "error": error_message
        }

        processed_data.append(record)

    try:
        with open(output_json_path, 'w', encoding='utf-8') as f:
            json.dump(processed_data, f, ensure_ascii=False, indent=4)
        print(f"\n✅ Saved labeled results to '{output_json_path}'")
    except Exception as e:
        print(f"❌ Error saving JSON: {e}")

# %%
if __name__ == "__main__":
    input_pickle_file = r"C:\Users\david\PY\golden_test_set_martino_extended_integer.pkl"
    output_json_file = r"C:\Users\david\PY\labeled_data_nano41_finetuned_high_and_main.json"
    process_pickle(input_pickle_file, output_json_file)
# Out:
# ✅ Loaded pickle 'C:\Users\david\PY\golden_test_set_martino_extended_integer.pkl' with 200 rows.
#
# 🔍 Processing record 1 (ID: 1560717328412823552)...
#
# 📨 Raw model output:
#  {"main": 10, "high": 4}
#
# 🔍 Processing record 2 (ID: 1498038424409817089)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 3 (ID: 1419340068314128385)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 4 (ID: 1512171601340497926)...
#
# 📨 Raw model output:
#  {"main": 3, "high": 5}
#
# 🔍 Processing record 5 (ID: 1481806570723885061)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 6 (ID: 1499383587732221952)...
#
# 📨 Raw model output:
#  {"main": 5, "high": 1}
#
# 🔍 Processing record 7 (ID: 1562035778389155840)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 8 (ID: 1498936437298843654)...
#
# 📨 Raw model output:
#  {"main": 5, "high": 1}
#
# 🔍 Processing record 9 (ID: 1533124506767593474)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 10 (ID: 1567081358526234625)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 11 (ID: 1501934846913908745)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 12 (ID: 1508099913011191808)...
#
# 📨 Raw model output:
#  {"main": 5, "high": 1}
#
# 🔍 Processing record 13 (ID: 1394817473845895170)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 14 (ID: 1560395750550421505)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 15 (ID: 1497576574186577928)...
#
# 📨 Raw model output:
#  {"main": 10, "high": 4}
#
# 🔍 Processing record 16 (ID: 1510632099937722369)...
#
# 📨 Raw model output:
#  {"main": 10, "high": 4}
#
# 🔍 Processing record 17 (ID: 1513156392739352577)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 18 (ID: 1503163918042411008)...
#
# 📨 Raw model output:
#  {"main": 6, "high": 4}
#
# 🔍 Processing record 19 (ID: 1500160716300455941)...
#
# 📨 Raw model output:
#  {"main": 5, "high": 1}
#
# 🔍 Processing record 20 (ID: 1501684664339157000)...
#
# 📨 Raw model output:
#  {"main": 9, "high": 5}
#
# 🔍 Processing record 21 (ID: 1497404993296474114)...
#
# 📨 Raw model output:
#  {"main": 4, "high": 4}
#
# 🔍 Processing record 22 (ID: 1503197120307900424)...
#
# 📨 Raw model output:
#  {"main": 4, "high": 4}
#
# 🔍 Processing record 23 (ID: 1520417622071906304)...
#
# 📨 Raw model output:
#  {"main": 10, "high": 4}
#
# 🔍 Processing record 24 (ID: 1499700631321387014)...
#
# 📨 Raw model output:
#  {"main": 9, "high": 5}
#
# 🔍 Processing record 25 (ID: 1513320202791960576)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 26 (ID: 1541526382118854656)...
#
# 📨 Raw model output:
#  {"main": 6, "high": 4}
#
# 🔍 Processing record 27 (ID: 1566384609851498502)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 28 (ID: 1501829863530852353)...
#
# 📨 Raw model output:
#  {"main": 5, "high": 1}
#
# 🔍 Processing record 29 (ID: 1526900255412871168)...
#
# 📨 Raw model output:
#  {"main": 4, "high": 4}
#
# 🔍 Processing record 30 (ID: 1515150523321798656)...
#
# 📨 Raw model output:
#  {"main": 9, "high": 5}
#
# 🔍 Processing record 31 (ID: 1557781972293910530)...
#
# 📨 Raw model output:
#  {"main": 5, "high": 1}
#
# 🔍 Processing record 32 (ID: 1499049911970455552)...
#
# 📨 Raw model output:
#  {"main": 5, "high": 1}
#
# 🔍 Processing record 33 (ID: 1498290915706048515)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 34 (ID: 1562050875987791874)...
#
# 📨 Raw model output:
#  {"main": 9, "high": 5}
#
# 🔍 Processing record 35 (ID: 1498883978002116611)...
#
# 📨 Raw model output:
#  {"main": 9, "high": 5}
#
# 🔍 Processing record 36 (ID: 1500380340648558596)...
#
# 📨 Raw model output:
#  {"main": 5, "high": 1}
#
# 🔍 Processing record 37 (ID: 1493086695511957504)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 38 (ID: 1496996091425918980)...
#
# 📨 Raw model output:
#  {"main": 7, "high": 3}
#
# 🔍 Processing record 39 (ID: 1508604884370829315)...
#
# 📨 Raw model output:
#  {"main": 9, "high": 5}
#
# 🔍 Processing record 40 (ID: 1521907652384727040)...
#
# 📨 Raw model output:
#  {"main": 3, "high": 5}
#
# 🔍 Processing record 41 (ID: 1503566412568137729)...
#
# 📨 Raw model output:
#  {"main": 9, "high": 5}
#
# 🔍 Processing record 42 (ID: 1530196701184671745)...
#
# 📨 Raw model output:
#  {"main": 2, "high": 4}
#
# 🔍 Processing record 43 (ID: 1497597178965073933)...
#
# 📨 Raw model output:
#  {"main": 9, "high": 5}
#
# 🔍 Processing record 44 (ID: 1519917458953363456)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 45 (ID: 1571338886487449600)...
#
# 📨 Raw model output:
#  {"main": 12, "high": 5}
#
# 🔍 Processing record 46 (ID: 1498990709248045059)...
#
# 📨 Raw model output:
#  {"main": 5, "high": 1}
#
# 🔍 Processing record 47 (ID: 1498084684374282243)...
#
# 📨 Raw model output:
#  {"main": 9, "high": 5}
#
# 🔍 Processing record 48 (ID: 1493607585005588495)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 49 (ID: 1498930884871073797)...
#
# 📨 Raw model output:
#  {"main": 5, "high": 1}
#
# 🔍 Processing record 50 (ID: 1501638954105417731)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 51 (ID: 1512931035683635212)...
#
# 📨 Raw model output:
#  {"main": 3, "high": 5}
#
# 🔍 Processing record 52 (ID: 1496906050175447046)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 53 (ID: 1504064288629014531)...
#
# 📨 Raw model output:
#  {"main": 5, "high": 1}
#
# 🔍 Processing record 54 (ID: 1502201384061792258)...
#
# 📨 Raw model output:
#  {"main": 5, "high": 1}
#
# 🔍 Processing record 55 (ID: 1513880170641383427)...
#
# 📨 Raw model output:
#  {"main": 7, "high": 3}
#
# 🔍 Processing record 56 (ID: 1558626862766637057)...
#
# 📨 Raw model output:
#  {"main": 5, "high": 1}
#
# 🔍 Processing record 57 (ID: 1500667111294877707)...
#
# 📨 Raw model output:
#  {"main": 4, "high": 4}
#
# 🔍 Processing record 58 (ID: 1539190420944695297)...
#
# 📨 Raw model output:
#  {"main": 3, "high": 5}
#
# 🔍 Processing record 59 (ID: 1503075443884400649)...
#
# 📨 Raw model output:
#  {"main": 5, "high": 1}
#
# 🔍 Processing record 60 (ID: 1496860029466599426)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 61 (ID: 1512648378328367109)...
#
# 📨 Raw model output:
#  {"main": 4, "high": 4}
#
# 🔍 Processing record 62 (ID: 1501831138268094477)...
#
# 📨 Raw model output:
#  {"main": 9, "high": 5}
#
# 🔍 Processing record 63 (ID: 1525050245951922176)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 64 (ID: 1499708523105554432)...
#
# 📨 Raw model output:
#  {"main": 4, "high": 4}
#
# 🔍 Processing record 65 (ID: 1557009163414380545)...
#
# 📨 Raw model output:
#  {"main": 9, "high": 5}
#
# 🔍 Processing record 66 (ID: 1502536898807431168)...
#
# 📨 Raw model output:
#  {"main": 9, "high": 5}
#
# 🔍 Processing record 67 (ID: 1508000207111401475)...
#
# 📨 Raw model output:
#  {"main": 3, "high": 5}
#
# 🔍 Processing record 68 (ID: 1496059783237013504)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 69 (ID: 1498219889257033736)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 70 (ID: 1504120736214048769)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 71 (ID: 1505728407103246339)...
#
# 📨 Raw model output:
#  {"main": 4, "high": 4}
#
# 🔍 Processing record 72 (ID: 1511019193877123072)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 73 (ID: 1537917334156759041)...
#
# 📨 Raw model output:
#  {"main": 5, "high": 1}
#
# 🔍 Processing record 74 (ID: 1535007753013452832)...
#
# 📨 Raw model output:
#  {"main": 9, "high": 5}
#
# 🔍 Processing record 75 (ID: 1497595556042092547)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 76 (ID: 1511275792004755456)...
#
# 📨 Raw model output:
#  {"main": 5, "high": 1}
#
# 🔍 Processing record 77 (ID: 1503923866774683653)...
#
# 📨 Raw model output:
#  {"main": 5, "high": 1}
#
# 🔍 Processing record 78 (ID: 1513426230166822916)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 79 (ID: 1507175139460661252)...
#
# 📨 Raw model output:
#  {"main": 16, "high": 2}
#
# 🔍 Processing record 80 (ID: 1499132864163508226)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 81 (ID: 1515264083095871490)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 82 (ID: 1506004211997286400)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 83 (ID: 1506522206960242691)...
#
# 📨 Raw model output:
#  {"main": 3, "high": 5}
#
# 🔍 Processing record 84 (ID: 1564332675019804673)...
#
# 📨 Raw model output:
#  {"main": 4, "high": 4}
#
# 🔍 Processing record 85 (ID: 1501920457821282307)...
#
# 📨 Raw model output:
#  {"main": 9, "high": 5}
#
# 🔍 Processing record 86 (ID: 1499263054864949248)...
#
# 📨 Raw model output:
#  {"main": 5, "high": 1}
#
# 🔍 Processing record 87 (ID: 1530071334050578433)...
#
# 📨 Raw model output:
#  {"main": 7, "high": 3}
#
# 🔍 Processing record 88 (ID: 1567421928390152192)...
#
# 📨 Raw model output:
#  {"main": 7, "high": 3}
#
# 🔍 Processing record 89 (ID: 1501810290823938051)...
#
# 📨 Raw model output:
#  {"main": 10, "high": 4}
#
# 🔍 Processing record 90 (ID: 1392782358789644288)...
#
# 📨 Raw model output:
#  {"main": 9, "high": 5}
#
# 🔍 Processing record 91 (ID: 1533370836144607232)...
#
# 📨 Raw model output:
#  {"main": 2, "high": 4}
#
# 🔍 Processing record 92 (ID: 1503912927417409538)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 93 (ID: 1539267819187195907)...
#
# 📨 Raw model output:
#  {"main": 6, "high": 4}
#
# 🔍 Processing record 94 (ID: 1547529139531534336)...
#
# 📨 Raw model output:
#  {"main": 10, "high": 4}
#
# 🔍 Processing record 95 (ID: 1517189986260602881)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 96 (ID: 1514193779254861832)...
#
# 📨 Raw model output:
#  {"main": 4, "high": 4}
#
# 🔍 Processing record 97 (ID: 1500287679178723329)...
#
# 📨 Raw model output:
#  {"main": 5, "high": 1}
#
# 🔍 Processing record 98 (ID: 1536710044204548096)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 99 (ID: 1569459285763178496)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 100 (ID: 1516974066174935041)...
#
# 📨 Raw model output:
#  {"main": 7, "high": 3}
#
# 🔍 Processing record 101 (ID: 1511140778168360966)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 102 (ID: 1503867252868853763)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 103 (ID: 1509483463866564612)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 104 (ID: 1508503613529853964)...
#
# 📨 Raw model output:
#  {"main": 6, "high": 4}
#
# 🔍 Processing record 105 (ID: 1506112300368863234)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 106 (ID: 1460531831741288452)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 107 (ID: 1501896416393936896)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 108 (ID: 1557258847978672129)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 109 (ID: 1498296622895312899)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 110 (ID: 1552454593187090435)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 111 (ID: 1496891390738980871)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 112 (ID: 1502333803913793542)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 113 (ID: 1519342803188387840)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 114 (ID: 1492520327259332623)...
#
# 📨 Raw model output:
#  {"main": 9, "high": 5}
#
# 🔍 Processing record 115 (ID: 1360281173025513480)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 116 (ID: 1503458233868075008)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 117 (ID: 1503835436879278080)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 118 (ID: 1535980365906583553)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 119 (ID: 1496911464095166465)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 120 (ID: 1496891136438329354)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 121 (ID: 1574465692795285504)...
#
# 📨 Raw model output:
#  {"main": 3, "high": 5}
#
# 🔍 Processing record 122 (ID: 1501254716625465344)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 123 (ID: 1553080377228644354)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 124 (ID: 1511360410620141569)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 125 (ID: 1543832783998558208)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 126 (ID: 1506005904503754759)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 127 (ID: 1522032841940471813)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 128 (ID: 1507323929098170368)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 129 (ID: 1497181831145398281)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 130 (ID: 1541494627764768770)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 131 (ID: 1374795277257867269)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 132 (ID: 1491439955100729346)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 133 (ID: 1514120256079417347)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 134 (ID: 1469351329764098055)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 135 (ID: 1390069717872824321)...
#
# 📨 Raw model output:
#  {"main": 4, "high": 4}
#
# 🔍 Processing record 136 (ID: 1497224117556232217)...
#
# 📨 Raw model output:
#  {"main": 15, "high": 1}
#
# 🔍 Processing record 137 (ID: 1361698932162785281)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 138 (ID: 1561109802906001408)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 139 (ID: 1573859589791141890)...
#
# 📨 Raw model output:
#  {"main": 6, "high": 4}
#
# 🔍 Processing record 140 (ID: 1471524044847697934)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 141 (ID: 1507415601827893249)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 142 (ID: 1469386882048004102)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 143 (ID: 1509967426271776778)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 144 (ID: 1502431421570428929)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 145 (ID: 1528054693997453313)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 146 (ID: 1502790748852437000)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 147 (ID: 1357743276275732480)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 148 (ID: 1499161349456338945)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 149 (ID: 1531484522524594176)...
#
# 📨 Raw model output:
#  {"main": 10, "high": 4}
#
# 🔍 Processing record 150 (ID: 1554559890315612160)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 151 (ID: 1499957407736164354)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 152 (ID: 1356699239884066818)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 153 (ID: 1508437808003919874)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 154 (ID: 1382116619942498308)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 155 (ID: 1527054097077116929)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 156 (ID: 1427289296772468739)...
#
# 📨 Raw model output:
#  {"main": 3, "high": 5}
#
# 🔍 Processing record 157 (ID: 1565246954795585536)...
#
# 📨 Raw model output:
#  {"main": 5, "high": 1}
#
# 🔍 Processing record 158 (ID: 1501799620204183552)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 159 (ID: 1507612662351695878)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 160 (ID: 1485801524647411713)...
#
# 📨 Raw model output:
#  {"main": 7, "high": 3}
#
# 🔍 Processing record 161 (ID: 1503563733590806529)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 162 (ID: 1426867956298964994)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 163 (ID: 1469770155169353728)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 164 (ID: 1535591518676955139)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 165 (ID: 1359268292280659978)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 166 (ID: 1373997432485388289)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 167 (ID: 1535460887871385600)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 168 (ID: 1478317280828088321)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 169 (ID: 1515342559899439112)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 170 (ID: 1499066811874037760)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 171 (ID: 1495789985466826757)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 172 (ID: 1545859945475760128)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 173 (ID: 1501118308707450884)...
#
# 📨 Raw model output:
#  {"main": 3, "high": 5}
#
# 🔍 Processing record 174 (ID: 1497963024052899845)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 175 (ID: 1472549667493892103)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 176 (ID: 1532042097871683586)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 177 (ID: 1566242418399350790)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 178 (ID: 1489673840158519304)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 179 (ID: 1531178629492658176)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 180 (ID: 1507838900554842115)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 181 (ID: 1519674848796200961)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 182 (ID: 1390258581249957888)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 183 (ID: 1504258971929960451)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 184 (ID: 1564613817262395396)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 185 (ID: 1563887519246082048)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 186 (ID: 1377098384226455557)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 187 (ID: 1542910520784830467)...
#
# 📨 Raw model output:
#  {"main": 4, "high": 4}
#
# 🔍 Processing record 188 (ID: 1575577594237689857)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 189 (ID: 1575577594237689858)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 190 (ID: 1575577594237689859)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 191 (ID: 1575577594237689860)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 192 (ID: 1575577594237689861)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 193 (ID: 1575577594237689862)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 194 (ID: 1575577594237689863)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 195 (ID: 1575577594237689864)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 196 (ID: 1575577594237689865)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 197 (ID: 1575577594237689866)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 198 (ID: 1575577594237689867)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 199 (ID: 1575577594237689868)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# 🔍 Processing record 200 (ID: 1575577594237689869)...
#
# 📨 Raw model output:
#  {"main": 18, "high": 6}
#
# ✅ Saved labeled results to 'C:\Users\david\PY\labeled_data_nano41_finetuned_high_and_main.json'
